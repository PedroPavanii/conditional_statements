# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroPavanii/conditional_statements/blob/main/projeto_SHARK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive 
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
tabela_shark = pd.read_excel('/drive/MyDrive/Shark/GSAF5.xls')
tabela_shark
# Out:
#              Date    Year        Type    Country               Area  \
# 0     25-Mar-2023  2023.0  Unprovoked        USA            Florida
# 1     22-Mar-2023  2023.0  Unprovoked  AUSTRALIA  Western Australia
# 2     19-Mar-2023  2023.0  Unprovoked        USA             Hawaii
# 3     17-Mar-2023  2023.0  Unprovoked     MEXICO       Quintana Roo
# 4     16-Mar-2023  2023.0  Unprovoked  AUSTRALIA  Western Australia
# ...           ...     ...         ...        ...                ...
# 6860          NaN     NaN         NaN        NaN                NaN
# 6861          NaN     NaN         NaN        NaN                NaN
# 6862          NaN     NaN         NaN        NaN                NaN
# 6863          NaN     NaN         NaN        NaN                NaN
# 6864          NaN     NaN         NaN        NaN                NaN
#
#                                         Location      Activity  \
# 0     Blue Fish Channel, Key West, Monroe County  Kite-Surfing
# ...

# %%
#Especies que mais atacaram no Brasil nos ultimos 10 anos

import matplotlib.pyplot as plt
especies_brasil_a = tabela_shark.loc[:,['Country','Species ','Year']]

especies_brasil_b = especies_brasil_a.loc[(especies_brasil_a['Country'] == 'BRAZIL') & (especies_brasil_a['Year'] >= 2003.)] 

especies_c =especies_brasil_b.dropna()

especies_d = especies_c[especies_c['Species '].isin(['Lemon shark pup','dogfish','Lemon shark', 'Tiger shark', 'small shark', 'Sandtiger shark','Tiger shark', 'Bull shark',' tiger shark', 'bull shark'])]
especies_e = especies_d.reset_index(drop = True)

especies_e['Species '] = especies_e['Species '].str.title()

especies_e.rename(columns={'Country': 'País', 'Species ': 'Espécies', 'Year': 'Ano'})

#falta grafico
# Out:
#       País         Espécies     Ano
# 0   BRAZIL          Dogfish  2021.0
# 1   BRAZIL  Lemon Shark Pup  2019.0
# 2   BRAZIL      Lemon Shark  2019.0
# 3   BRAZIL      Tiger Shark  2018.0
# 4   BRAZIL      Small Shark  2018.0
# 5   BRAZIL  Lemon Shark Pup  2017.0
# 6   BRAZIL  Sandtiger Shark  2016.0
# 7   BRAZIL  Sandtiger Shark  2016.0
# 8   BRAZIL       Bull Shark  2008.0
# 9   BRAZIL      Tiger Shark  2006.0
# 10  BRAZIL       Bull Shark  2004.0
# 11  BRAZIL       Bull Shark  2004.0
# 12  BRAZIL       Bull Shark  2003.0
