# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroPavanii/conditional_statements/blob/main/projeto_SHARK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Trabalho de limpeza e apresentações dos dados relativos aos ataques de tubarões no mundo. A cada celula discorro a pergunta chave e como cheguei no resultado com códigos comentados.**

# %% [markdown]
# ## **Importando as bibliotecas e exibindo a tabela principal de trabalho.**

# %%
import pandas as pd
import numpy as np
from google.colab import drive 
drive.mount('/drive')
tabela_shark = pd.read_excel('/drive/MyDrive/Shark/GSAF5.xls')


tabela_shark['Year'].unique()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# array([2023., 2022., 2021., 2020., 2019., 2018., 2017.,   nan, 2016.,
#        2015., 2014., 2013., 2012., 2011., 2010., 2009., 2008., 2007.,
#        2006., 2005., 2004., 2003., 2002., 2001., 2000., 1999., 1998.,
#        1997., 1996., 1995., 1984., 1994., 1993., 1992., 1991., 1990.,
#        1989., 1969., 1988., 1987., 1986., 1985., 1983., 1982., 1981.,
#        1980., 1979., 1978., 1977., 1976., 1975., 1974., 1973., 1972.,
#        1971., 1970., 1968., 1967., 1966., 1965., 1964., 1963., 1962.,
#        1961., 1960., 1959., 1958., 1957., 1956., 1955., 1954., 1953.,
#        1952., 1951., 1950., 1949., 1948., 1848., 1947., 1946., 1945.,
#        1944., 1943., 1942., 1941., 1940., 1939., 1938., 1937., 1936.,
#        1935., 1934., 1933., 1932., 1931., 1930., 1929., 1928., 1927.,
#        1926., 1925., 1924., 1923., 1922., 1921., 1920., 1919., 1918.,
# ...

# %% [markdown]
# ## **1) Quais as espécies que mais atacaram no Brasil nos ultimos 10 anos?**

# %%
#ESTABELECENDO FILTROS PARA RESPONDER A QUESTÃO ACIMA.
especies_brasil_a = tabela_shark.loc[:,['Country','Year', 'Species ']]
especies_brasil_b = especies_brasil_a.loc[(especies_brasil_a['Country'] == 'BRAZIL') & (especies_brasil_a['Year'] >= 2003.)] 
especies_c =especies_brasil_b.dropna()


#RETIRANDO TODOS OS NULOS, NOMES DE ESPECIES ERRADOS E VALORES NÃO PERTENCENTES.
especies_d = especies_c[especies_c['Species '].isin(['Lemon shark pup','dogfish','Lemon shark', 'Tiger shark', 'small shark', 'Sandtiger shark','Tiger shark', 'Bull shark',' tiger shark', 'bull shark'])]
especies_final = especies_d.reset_index(drop = True)


#MELHORANDO ESTETICA DA APRESENTAÇÃO DOS VALORES NAS COLUNAS.
especies_final['Species '] = especies_final['Species '].str.title()


#TRADUZINDO AS COLUNAS PARA PORTUGUÊS.
especies_final = especies_final.rename(columns={'Country': 'País', 'Species ': 'Espécies', 'Year': 'Ano'})


#RETIRANDO A COLUNA PAÍS.
especies_final = especies_final.drop('País', axis = 1)
especies_final = especies_final.drop('Ano', axis = 1)


#CRIANDO UM DATAFRAME PARA RELACIONAR ESPECIES POR ANO.
df_especies_final=especies_final.value_counts().reset_index()
df_especies_final.columns = [ 'Species', 'Nº of Atack']


df_especies_final
#FALTA GRAFICO
# Out:
#            Species  Nº of Atack
# 0       Bull Shark            4
# 1  Lemon Shark Pup            2
# 2  Sandtiger Shark            2
# 3      Tiger Shark            2
# 4          Dogfish            1
# 5      Lemon Shark            1
# 6      Small Shark            1

# %% [markdown]
# ## **2) Quais as praias do brasil que mais tiveram incidentes?**

# %%
#FILTRANDO AS PRAIAS DO BRASIL POR AREA E LOCALIZAÇÃO. RETIRANDO VALORES NULOS E LINHAS COM RESULTADOS NÃO PERTENCENTES.
praias = tabela_shark.loc[:,['Country','Area','Location']]
praias_br = praias.loc[praias['Country'] =='BRAZIL'].dropna().reset_index(drop=True)
praias_br.drop(index =[110, 13, 20, 36], inplace = True)


#REALIZANDO FILTRAGEM, SUBSTITUIÇÃO DE VALORES VISANDO MELHORA ESTETICA E MELHOR VISUALIZAÇÃO.
praias_br['Area']= praias_br['Area'].str.replace(r'\.', ' ', regex=True)
praias_br['Location']= praias_br['Location'].str.replace(r',.*', '', regex=True)
praias_br['Location']= praias_br['Location'].str.replace('Punta Del Chifre', 'Praia Del Chifre')
praias_br['Location']= praias_br['Location'].str.replace('Beach', '')
praias_br['Location']= praias_br['Location'].str.replace('beach', '')
praias_br = praias_br.drop('Country', axis=1)


#CRIANDO UM DATAFRAME QUE RELACIONE AS PRAIAS COM OS INCIDENTES.
df_praia = praias_br['Location'].value_counts().reset_index()
df_praia.columns = ['Beach', 'Nº of Atack']
df_praia.set_index('Beach', inplace=True)

df_praia


#praias repetidas nao agruparam
#FALTA GRAFICO
# Out:
#                                  Nº of Atack
# Beach
# Piedade                                   17
# Boa Viagem                                14
# Piedade                                   11
# Boa Viagem                                 9
# Copacabana                                 4
# Paiva                                      4
# Pina                                       3
# Cabo Frio                                  2
# Candeias                                   2
# Praia do Pina                              2
# Praia Del Chifre                           2
# Rio de Janeiro                             2
# Praia da Marcela                           2
# Copacabana                                 2
# Barra de Jangada                           2
# Ilhéus                                     1
#  Boa Viagem                                1
# Praia de São Marcus                        1
# Praia de Pau Amarelo                       1
# Manguinhos                                 1
# ...

# %% [markdown]
# ## **3)Quais as praias que tiveram o maior numeros de incidentes no mundo?**

# %%
#IDENTIFICANDO AS PRAIAS DO MUNDO E FILTRANDO AS 5 PRIMEIRAS COM MAIS ATAQUES.
praias_mundo = tabela_shark.loc[:,['Country','Area','Location']]
praias_top5 = praias_mundo.value_counts().head(5)



#REALIZANDO A CRIAÇÃO DE UM DATAFRAME QUE MOSTRE AS 5 PRIMEIRAS RELACIONANDO COM O NUMERO DE ATAQUES.
df_praias_top5 = praias_top5.to_frame().reset_index()
df_praias_top5.columns = ['index','State', ' Beach', 'Nº of Atack'] 
df_praias_top5 = df_praias_top5.drop('index',axis=1)
df_praias_top5.set_index('State', inplace=True)


df_praias_top5

#FALTA GRAFICO
# Out:
#                                            Beach  Nº of Atack
# State
# Florida         New Smyrna Beach, Volusia County          189
# Florida            Daytona Beach, Volusia County           31
# Florida              Ponce Inlet, Volusia County           26
# South Carolina        Myrtle Beach, Horry County           21
# Florida          Melbourne Beach, Brevard County           20

# %% [markdown]
# ## **4) Quais foram os tipos de atividades exercidas no momento do ataque e suas respectivas consequencias?**

# %%
#FILTRANDO ATIVIDADES, INJURIAS NO BRASIL.
ataques_ativ = tabela_shark.loc[:,['Country', 'Activity', 'Injury']]
ativ = ataques_ativ.loc[ataques_ativ['Country']=='BRAZIL'].dropna().drop('Country',axis=1)


#TRANSFORMANDO EM DATAFRAME O NUMERO DE ATAQUES POR ATIVIDADE.
df_ativ = ativ['Activity'].value_counts().head(5).to_frame().reset_index()
df_ativ.columns = ['Activity', 'Nº de Atack']
df_ativ.set_index('Activity', inplace=True)

df_ativ
# Out:
#                Nº de Atack
# Activity
# Surfing                 39
# Swimming                34
# Fishing                  4
# Body boarding            4
# Swimming                 3

# %% [markdown]
# ### 4.1) RESULTADOS DOS ATAQUES/SWIMMING

# %%
#FILTRAR RESULTADOS DOS ATAQUES/SWIMMING.
swimming = ataques_ativ.loc[ataques_ativ['Country']=='BRAZIL'].dropna().drop('Country',axis=1)
swimming = swimming.loc[swimming['Activity']=='Swimming']


#CRIAR DATAFRAME MOSTRANDO NUMERO DE CASOS DE INJURIAS. 
df_swimming = swimming['Injury'].value_counts().to_frame().reset_index()
df_swimming.columns = ['Injury', 'Nº of Cases']



#REALIZANDO LIMPEZA PARA MELHOR VISUALIZAÇÃO.
df_swimming['Injury'] = df_swimming['Injury'].str.replace(r'FATAL.*', 'Fatal', regex=True)
df_swimming['Injury'] = df_swimming['Injury'].str.replace(r'^.*Fatal', 'Fatal', regex=True)
df_swimming.set_index('Injury', inplace=True)



df_swimming

#somar linhas
# Out:
#                                                     Nº of Cases
# Injury
# Fatal                                                        15
# Right leg bitten                                              2
# Hand severed, buttocks bitten                                 1
# Fatal                                                         1
# Left thigh bitten, leg surgically amputated                   1
# Fatal                                                         1
# Right hand lacerated                                          1
# Fatal                                                         1
# Left hand, foot severed &  left calf & arm bitten             1
# Left leg bitten                                               1
# Left arm severly injured                                      1
# Right thigh bitten resulting in surgical amputa...            1
# Cause of death may have been drowning; remains ...            1
# Lacerations to scalp                                          1
# ...

# %% [markdown]
# ### 4.2) RESULTADOS DOS ATAQUES/SURFING

# %%
#FILTRAR RESULTADOS DOS ATAQUES/SURFING.
surfing = ataques_ativ.loc[ataques_ativ['Country']=='BRAZIL'].dropna().drop('Country',axis=1)
surfing = surfing.loc[surfing['Activity']=='Surfing']


#CRIAR DATAFRAME MOSTRANDO NUMERO DE CASOS DE INJURIAS. 
df_surfing = surfing['Injury'].value_counts().to_frame().reset_index()
df_surfing.columns = ['Injury', 'Nº of Cases']



#REALIZANDO LIMPEZA PARA MELHOR VISUALIZAÇÃO.
df_surfing['Injury'] = df_surfing['Injury'].str.replace(r'FATAL.*', 'Fatal', regex=True)
df_surfing['Injury'] = df_surfing['Injury'].str.replace(r'^.*Fatal', 'Fatal', regex=True)
df_surfing.set_index('Injury', inplace=True)



df_surfing

#somar linhas
# Out:
#                                                     Nº of Cases
# Injury
# Survived                                                      8
# Leg bitten                                                    2
# Right thigh bitten                                            2
# Foot bitten                                                   2
# Fatal                                                         2
# Injuries to left thih and calf                                1
# Leg injured                                                   1
# Arm bitten                                                    1
# Left foot severed                                             1
# Fatal                                                         1
# Lacerations to left foot                                      1
# Right leg bitten                                              1
# Fatal                                                         1
# Leg & hands bitten                                            1
# ...

# %% [markdown]
# ### 4.3) RESULTADOS DOS ATAQUES/FISHING

# %%
#FILTRAR RESULTADOS DOS ATAQUES/FISHING.
fishing = ataques_ativ.loc[ataques_ativ['Country']=='BRAZIL'].dropna().drop('Country',axis=1)
fishing = fishing.loc[fishing['Activity']=='Fishing']


#CRIAR DATAFRAME MOSTRANDO NUMERO DE CASOS DE INJURIAS. 
df_fishing = fishing['Injury'].value_counts().to_frame().reset_index()
df_fishing.columns = ['Injury', 'Nº of Cases']


#REALIZANDO LIMPEZA PARA MELHOR VISUALIZAÇÃO.
df_fishing['Injury'] = df_fishing['Injury'].str.replace(r'FATAL.*', 'Fatal', regex=True)
df_fishing['Injury'] = df_fishing['Injury'].str.replace(r'^.*Fatal', 'Fatal', regex=True)
df_fishing.set_index('Injury', inplace=True)


df_fishing

#somar linhas
# Out:
#                                                     Nº of Cases
# Injury
# Cut to toe from hooked shark PROVOKED INCIDENT                1
# Injury to ankle from marine animal trapped in w...            1
# Severe injury to arm                                          1
# 2 fingers severed by netted shark PROVOKED INCI...            1

# %% [markdown]
# 4.4) RESULTADOS DOS ATAQUES/BODY BOARDING

# %%
#FILTRAR RESULTADOS DOS ATAQUES/Body boarding.
body_boarding = ataques_ativ.loc[ataques_ativ['Country']=='BRAZIL'].dropna().drop('Country',axis=1)
body_boarding = body_boarding.loc[body_boarding['Activity']=='Body boarding']


#CRIAR DATAFRAME MOSTRANDO NUMERO DE CASOS DE INJURIAS. 
df_body_boarding = swimming['Injury'].value_counts().to_frame().reset_index()
df_body_boarding.columns = ['Injury', 'Nº of Cases']



#REALIZANDO LIMPEZA PARA MELHOR VISUALIZAÇÃO.
df_body_boarding['Injury'] = df_body_boarding['Injury'].str.replace(r'FATAL.*', 'Fatal', regex=True)
df_body_boarding['Injury'] = df_body_boarding['Injury'].str.replace(r'^.*Fatal', 'Fatal', regex=True)
df_body_boarding.set_index('Injury', inplace=True)



df_body_boarding

#somar linhas
# Out:
#                                                     Nº of Cases
# Injury
# Fatal                                                        15
# Right leg bitten                                              2
# Hand severed, buttocks bitten                                 1
# Fatal                                                         1
# Left thigh bitten, leg surgically amputated                   1
# Fatal                                                         1
# Right hand lacerated                                          1
# Fatal                                                         1
# Left hand, foot severed &  left calf & arm bitten             1
# Left leg bitten                                               1
# Left arm severly injured                                      1
# Right thigh bitten resulting in surgical amputa...            1
# Cause of death may have been drowning; remains ...            1
# Lacerations to scalp                                          1
# ...

# %% [markdown]
# ## **5)Qual a média de ataques por sexo no Brasil e no pais lider de ataques no Mundo desde 1500 até 2023?**

# %% [markdown]
# ### **5.1) Brasil**

# %%
ataques_br = tabela_shark.loc[:,['Country', 'Sex ']]

ataques_br = ataques_br.loc[ataques_br['Country'] == 'BRAZIL'].dropna().value_counts().to_frame().reset_index()
ataques_br.columns = ['index','Sex','Attack']
ataques_br = ataques_br.drop('index',axis = 1)
ataques_br.set_index('Sex', inplace =True)
ataques_br
# Out:
#      Attack
# Sex
# M       102
# F         6

# %%
ataques_mundo = tabela_shark.loc[:,['Country']]

ataques_mundo = ataques_mundo.loc[ataques_mundo['Country'] != 'BRAZIL'].dropna().value_counts().head(5).to_frame().reset_index()
ataques_mundo.columns = ['Country', 'Nº of Cases']
ataques_mundo.set_index('Country', inplace = True)
ataques_mundo
# Out:
#                   Nº of Cases
# Country
# USA                      2495
# AUSTRALIA                1460
# SOUTH AFRICA              593
# NEW ZEALAND               142
# PAPUA NEW GUINEA          136

# %%
ataques_usa = tabela_shark.loc[:,['Country', 'Sex ']]
ataques_usa = ataques_usa.loc[ataques_usa['Country'] == 'USA'].dropna().value_counts().to_frame().reset_index()
ataques_usa.columns = ['index','Sex','Attack']
ataques_usa = ataques_usa.drop('index',axis = 1)
ataques_usa.set_index('Sex', inplace =True)
ataques_usa
# Out:
#        Attack
# Sex
# M        1987
# F         401
#  M          1
# M           1
# M x 2       1
# lli         1

# %% [markdown]
# ## **6) Quais os meses do ano que ocorrem mais ataques no Brasil?**

# %%
meses= tabela_shark.loc[:,['Country', 'Date']]
meses = meses.loc[meses['Country'] == 'BRAZIL'].dropna().value_counts().to_frame().reset_index()
meses= pd.DataFrame({'Date': pd.date_range(start='2022-01-01', end='2022-12-31', freq='D').strftime('%b')
})
# Out:
#     Country                  Date  0
# 0    BRAZIL           08-Jul-1992  2
# 1    BRAZIL           28-Oct-1996  2
# 2    BRAZIL           23-Apr-2003  2
# 3    BRAZIL           22-Jul-2013  1
# 4    BRAZIL           24-Mar-2002  1
# ..      ...                   ... ..
# 114  BRAZIL           08-Jul-1994  1
# 115  BRAZIL           07-Sep-2009  1
# 116  BRAZIL           07-Jun-1997  1
# 117  BRAZIL           07-Jul-1995  1
# 118  BRAZIL  Reported 28-Apr-1884  1
#
# [119 rows x 3 columns]

# %% [markdown]
# ## **7) Portos?**
